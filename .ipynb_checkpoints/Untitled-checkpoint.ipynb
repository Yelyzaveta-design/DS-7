# %% [markdown]
# # Проектна робота
# ## на тему: "Прогноз ціни оренди на квартири в Києві"
# ### студенти: Андрій Скрипник та Єлизавета Разгонова

# %% [markdown]
# ### Обмеження :
# 1. Дані беремо тільки по КИєву
# 2. Дані лише по багатоквартирним будинкам
# 3. Не аналізуємо хостели, гуртожитки, подобова оренда
# 4. Все в грн

# %% [markdown]
# Для збору інформації був використаний сайт:

# %%
pip install lxml
pip install beautifulsoup4
