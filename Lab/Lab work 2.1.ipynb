# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 2: Basic Python

# %% [markdown]
# ## Lab work 2.1

# %% [markdown]
# #### Мета:
#
# * навчитися працювати із основними типами та структурами даних в Python;
# * ознайомитися із базовими алгоритмами;

# %% [markdown]
# #### Завдання 1

# %% [markdown]
# Обчислити площу трикутника, коли відома сторона та проведена висота до неї

# %%
import math
a = int(input('Довжина сторони трикутника' , ))
h = int(input('Довжина висоти' , ))
S = (math.sqrt (a*h))
print ('Площа трикутника', S)

# %% [markdown]
# #### Завдання 2

# %% [markdown]
# Дано трицифрове число. Виведіть окремо кожну цифру числа та суми цифр число
#
# Реалізуйте завдання двома способами (використовуючи стрічки та оператори `%`, `//`)

# %%
N = input()
a = N [0]
b = N [1]
c = N [2]
print ('Перше число', a)
print ('Друге число', b)
print ('Третє число', c)
S = (a+b+c)
print ('Сума всіх чисел', S)
# Out:
# 345
# Перше число 3
# Друге число 4
# Третє число 5
# Сума всіх чисел 345

# %%
N = int(input())
c = N % 10
print ('Третє число', c)
N = N // 10
b = N % 10
print ('Друге число', b)
a = N // 10
print ('Перше число', a)
print ('Сума всіх чисел', a+b+c)
# Out:
# 345
# Третє число 5
# Друге число 4
# Перше число 3
# Сума всіх чисел 12

# %% [markdown]
# #### Завдання 3

# %% [markdown]
# Дано речення (стрічка).
# * Розбийте речення по словах і помістіть їх у список.
# * Виведіть кількість слів у речені.
# * Утворіть нове речення, що складається з першого та останнього слова із початкового речення.

# %%
sentence = 'My favourite tutor in academy is Ihor'
words = sentence.split ()
print (words)
print ('Кількість слів у речені', len(words))
new_sentence = words [0], words [-1]
x = " ".join(new_sentence)
print ('Нове речення', x)
# Out:
# ['My', 'favourite', 'tutor', 'in', 'academy', 'is', 'Ihor']
# Кількість слів у речені 7
# Нове речення My Ihor

# %% [markdown]
# #### Завдання 4

# %% [markdown]
# Перевірте, чи справджується формула: $$ sin^2x + cos^2x = 1$$
#
# Напишіть код, що реалізує цю формулу. Нагадую, що тригонометричні функції приймають аргументи в радіанній мірі

# %%
import cmath

x = int(input())
formula = cmath.sqrt(cmath.sin(x)) + cmath.sqrt(cmath.cos(x))
if formula == 1:
    print('True')
else:
    print('False')
# Out:
# 5
# False

# %% [markdown]
# #### Завдання 5

# %% [markdown]
# Напишіть програму для обчислення коренів квадратного рівняння.
#
# Нагадую, що `n`-го степеня має `n` коренів. (Корені можуть бути комплексні)

# %%
import cmath
print ('Вирішення квадратного рівняння')
a = int(input('Введіть значення a', ))
b = int(input('Введіть значення b', ))
c = int(input('Введіть значення c', ))
D = b**2 - 4*a*c
print (D)
if D < 0:
    print ('Коренів немає')
elif D == 0:
    x = -b/2*a
    print (x)
else:
    x1 = (-b + cmath.sqrt(D)) / (2*a)
    x2 = (-b - cmath.sqrt(D)) / (2*a)
    print (x1, x2)

# %% [markdown]
# #### Завдання 6

# %% [markdown]
# Напишіть програму, що виводить речення: <i>"Діаметр планети `Planet` дорівнює` Diament`"</i>,
#
# де `Planet` та `Diament` вводить користувач

# %%
first_word = str(input('Перше слово ')) 
second_word = str(input('Друге слово '))
print ('Діаметр планети', first_word, 'дорівнює', second_word)
# Out:
# Перше слово Planet
# Друге слово Diament
# Діаметр планети Planet дорівнює Diament
