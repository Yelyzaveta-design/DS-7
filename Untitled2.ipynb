# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
conda install scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting package metadata (current_repodata.json): ...working... done
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Magnolia\miniconda3
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     ca-certificates-2021.9.30  |       haa95532_1         116 KB
#     icc_rt-2019.0.0            |       h0cc432a_1         6.0 MB
#     intel-openmp-2021.3.0      |    haa95532_3372         2.0 MB
#     joblib-1.0.1               |     pyhd3eb1b0_0         208 KB
#     mkl-2021.3.0               |     haa95532_524       113.7 MB
#     mkl-service-2.4.0          |   py37h2bbff1b_0          49 KB
# ...

# %%
db = r'C:\Users\Magnolia\Desktop\Main Academy\data base.sqlite'

# %%
flats_rent = pd.read_sql('SELECT *FROM flats', sqlite3.connect(db)).set_index('id')
flats_rent.sample(10)
# Out:
#           Ціна  Площа  Поверх  Всього поверхів  К-сть кімнат          Район  \
# id
# 5485187  18528   78.0       2                5             1      Печерский
# 5489693  21500  100.0       7               18             3   Голосеевский
# 5371923  15500   70.0       4               25             2      Дарницкий
# 5402869  38381  135.0      14               16             3      Печерский
# 5477248  66174  180.0       4               24             4      Печерский
# 5393174  17000   37.0       7               24             1      Дарницкий
# 4750642  16000   43.0      10               22             1      Дарницкий
# 5484849  26469   57.0       3               19             2      Печерский
# 5462275  37057   57.0       3                5             2  Шевченковский
# 5271304  47645  126.0       9               15             4  Шевченковский
#
#                   Мікрорайон  ЖК          x          y  Відстань до метро  \
# id
# ...

# %%
flats_rent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12555 entries, 5503394 to 4098231
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ціна               12555 non-null  int64
#  1   Площа              12555 non-null  float64
#  2   Поверх             12555 non-null  int64
#  3   Всього поверхів    12555 non-null  int64
#  4   К-сть кімнат       12555 non-null  int64
#  5   Район              12555 non-null  object
#  6   Мікрорайон         12555 non-null  object
#  7   ЖК                 12555 non-null  int64
#  8   x                  12555 non-null  float64
#  9   y                  12555 non-null  float64
#  10  Відстань до метро  12555 non-null  float64
#  11  Престиж району     12555 non-null  float64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 1.2+ MB

# %%
flats_rent.describe()
# Out:
#                Ціна         Площа        Поверх  Всього поверхів  \
# count  1.255500e+04  12555.000000  12555.000000     12555.000000
# mean   4.656928e+04     87.952236      9.181282        17.256312
# std    5.577168e+04     59.138851      6.303420         8.172571
# min    4.200000e+03      1.000000      1.000000         1.000000
# 25%    1.800000e+04     52.000000      4.000000         9.000000
# 50%    3.250000e+04     71.000000      8.000000        18.000000
# 75%    5.293900e+04    109.000000     13.000000        24.000000
# max    2.022287e+06   1900.000000     40.000000        50.000000
#
#        К-сть кімнат            ЖК             x             y  \
# count  12555.000000  12555.000000  12555.000000  12555.000000
# mean       2.339307      0.421824     50.434011     30.526883
# std        1.050598      0.493870      0.031833      0.057371
# min        1.000000      0.000000     50.301089     30.326641
# 25%        2.000000      0.000000     50.411005     30.499609
# ...

# %%
sns.pairplot(flats_rent)

# %%
flats_rent.corr()
# Out:
#                        Ціна     Площа    Поверх  Всього поверхів  \
# Ціна               1.000000  0.703575  0.112131         0.093789
# Площа              0.703575  1.000000  0.079309         0.026187
# Поверх             0.112131  0.079309  1.000000         0.639168
# Всього поверхів    0.093789  0.026187  0.639168         1.000000
# К-сть кімнат       0.500009  0.730664  0.056217        -0.007402
# ЖК                 0.120212 -0.038182  0.227139         0.401370
# x                 -0.124094 -0.046588 -0.161470        -0.251613
# y                  0.026691  0.012659  0.109751         0.171405
# Відстань до метро -0.204169 -0.181435 -0.069949        -0.107907
# Престиж району     0.328255  0.303054 -0.019082         0.018788
#
#                    К-сть кімнат        ЖК         x         y  \
# Ціна                   0.500009  0.120212 -0.124094  0.026691
# Площа                  0.730664 -0.038182 -0.046588  0.012659
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x = flats_rent[['Площа', 'Поверх', 'Всього поверхів', 'К-сть кімнат', 'ЖК', 'Відстань до метро', 'Престиж району']]
y = flats_rent ['Ціна']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
lm = LinearRegression()
lm.fit(x_train, y_train)
# Out:
# LinearRegression()
